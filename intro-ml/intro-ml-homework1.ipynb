# %%
# !pip install jupyter numpy pandas scikit-learn seaborn

# %% [markdown]
# ## Q1. Pandas version
#
# What version of Pandas did you install?
#
# You can get the version information using the `__version__` field:

# %%
# !pip install --upgrade pandas

# %%
import pandas as pd
import numpy as np
print(pd.__version__)
# Out:
# 3.0.6

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# '/Users/foroghakbari/Zoomcamp/ml_course/zoomcamp_ml/intro-ml'

# %%
df = pd.read_csv('/Users/foroghakbari/Zoomcamp/ml_course/zoomcamp_ml/intro-ml/data/car_fuel_efficiency_2026.csv')

# %% [markdown]
# ## Q2. Records count
#
# How many records are in the dataset?

# %%
print(df.count())
# Out:
# model_year             10000
# origin                 10000
# fuel_type              10000
# drivetrain             10000
# num_doors              10000
# engine_displacement    10000
# num_cylinders          10000
# horsepower              9123
# vehicle_weight         10000
# acceleration            9736
# fuel_efficiency_mpg    10000
# dtype: int64

# %%
df
# Out:
#       model_year  origin fuel_type         drivetrain  num_doors  \
# 0           2006  Europe  Gasoline  Front-wheel drive          4
# 1           2008  Europe    Diesel  Front-wheel drive          4
# 2           1996    Asia  Gasoline  Front-wheel drive          5
# 3           1989  Europe  Gasoline  Front-wheel drive          4
# 4           1994     USA    Diesel  Front-wheel drive          3
# ...          ...     ...       ...                ...        ...
# 9995        2005     USA  Gasoline    All-wheel drive          4
# 9996        1993    Asia  Gasoline    All-wheel drive          2
# 9997        2014     USA  Gasoline    All-wheel drive          3
# 9998        2004     USA    Hybrid   Rear-wheel drive          5
# 9999        2011     USA    Diesel  Front-wheel drive          4
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                    2180              6       243.0            3870
# ...

# %%
df.fuel_type
# Out:
# 0       Gasoline
# 1         Diesel
# 2       Gasoline
# 3       Gasoline
# 4         Diesel
#           ...
# 9995    Gasoline
# 9996    Gasoline
# 9997    Gasoline
# 9998      Hybrid
# 9999      Diesel
# Name: fuel_type, Length: 10000, dtype: str

# %% [markdown]
# ## Q3. Fuel types

# %%
df["fuel_type"].unique()
# 3 types
# Out:
# <ArrowStringArray>
# ['Gasoline', 'Diesel', 'Hybrid']
# Length: 3, dtype: str

# %% [markdown]
# ## Q4. Missing values

# %%
df.count() #2 cols that are missing
# Out:
# model_year             10000
# origin                 10000
# fuel_type              10000
# drivetrain             10000
# num_doors              10000
# engine_displacement    10000
# num_cylinders          10000
# horsepower              9123
# vehicle_weight         10000
# acceleration            9736
# fuel_efficiency_mpg    10000
# dtype: int64

# %%
#get NAN count 
df.count()
sum(df.isnull().sum())
# Out:
# 1141

# %% [markdown]
# ## Q5. Max fuel efficiency

# %%
#subset cars from origin from asia 
asia_df = df[df["origin"] == "Asia"]

# %%
max(asia_df.fuel_efficiency_mpg)
# Out:
# 41.2

# %% [markdown]
# ## Q6. Median value of horsepower
# Find the median value of the horsepower column in the dataset.
# Next, calculate the most frequent value of the same horsepower column.
# Use the fillna method to fill the missing values in the horsepower column with the most frequent value from the previous step.
# Now, calculate the median value of horsepower once again.

# %%
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %%
df["horsepower"].median()
# Out:
# 254.0

# %%
df["horsepower"].value_counts()
# Out:
# horsepower
# 252.0    174
# 246.0    168
# 256.0    168
# 259.0    165
# 253.0    165
#         ...
# 322.0      1
# 330.0      1
# 175.0      1
# 178.0      1
# 320.0      1
# Name: count, Length: 153, dtype: int64

# %%
df.fillna(value="horsepower")
# Out:
#       model_year  origin fuel_type         drivetrain  num_doors  \
# 0           2006  Europe  Gasoline  Front-wheel drive          4
# 1           2008  Europe    Diesel  Front-wheel drive          4
# 2           1996    Asia  Gasoline  Front-wheel drive          5
# 3           1989  Europe  Gasoline  Front-wheel drive          4
# 4           1994     USA    Diesel  Front-wheel drive          3
# ...          ...     ...       ...                ...        ...
# 9995        2005     USA  Gasoline    All-wheel drive          4
# 9996        1993    Asia  Gasoline    All-wheel drive          2
# 9997        2014     USA  Gasoline    All-wheel drive          3
# 9998        2004     USA    Hybrid   Rear-wheel drive          5
# 9999        2011     USA    Diesel  Front-wheel drive          4
#
#       engine_displacement  num_cylinders horsepower  vehicle_weight  \
# 0                    2180              6      243.0            3870
# ...

# %%
df["horsepower"].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: horsepower, Length: 10000, dtype: bool

# %%
df["horsepower"].median()
# Out:
# 254.0

# %% [markdown]
# ## Q7. Sum of weights
#
# 1. Select all the cars from Asia
# 2. Select only columns `vehicle_weight` and `model_year`
# 3. Select the first 7 values
# 4. Get the underlying NumPy array. Let's call it `X`.
# 5. Compute matrix-matrix multiplication between the transpose of `X` and `X`. To get the transpose, use `X.T`. Let's call the result `XTX`.
# 6. Invert `XTX`.
# 7. Create an array `y` with values `[1100, 1300, 800, 900, 1000, 1100, 1200]`.
# 8. Multiply the inverse of `XTX` with the transpose of `X`, and then multiply the result by `y`. Call the result `w`.
# 9. What's the sum of all the elements of the result?

# %%
asia_df_sub = asia_df[["vehicle_weight", "model_year"]]

# %%
asia_df_sub.head(7)
# Out:
#     vehicle_weight  model_year
# 2             4240        1996
# 6             4310        1992
# 8             4230        1997
# 10            4420        1978
# 15            3950        2007
# 16            4750        2021
# 22            4450        2019

# %%
X = asia_df_sub.head(7)

# %%
XTX = X.T

# %%
print(XTX)
# Out:
#                   2     6     8     10    15    16    22
# vehicle_weight  4240  4310  4230  4420  3950  4750  4450
# model_year      1996  1992  1997  1978  2007  2021  2019

# %%
# 2. Compute the true matrix multiplication (this creates a square 2x2 matrix)
XTX_actual = X.T @ X

# 3. Now invert the square matrix without errors
XTX_inv = np.linalg.inv(XTX_actual)

# %%
XTX_inv
# Out:
# array([[ 2.96830537e-06, -6.43071025e-06],
#        [-6.43071025e-06,  1.39675281e-05]])

# %%
y = [1100, 1300, 800, 900, 1000, 1100, 1200]

# %%
XTX_inv_XT = XTX_inv.dot(X.T)

# %%
w=XTX_inv_XT.dot(y)

# %%
w.sum()
# Out:
# 0.369196969049255
