# %%
# 1. Fix the "remote origin already exists" error by removing the old link
# !git remote remove origin
# !git remote add origin https://github.com/foroghakbari/Zoomcamp_homework.git

# 2. Fix the "src refspec main does not match" error by tracking and committing files
# !git add .
# !git commit -m "Upload Zoomcamp homework folder"

# 3. Rename the branch and push your files online
# !git branch -M main
# !git push -u origin main
# Out:
# ^C
# KeyboardInterrupt
