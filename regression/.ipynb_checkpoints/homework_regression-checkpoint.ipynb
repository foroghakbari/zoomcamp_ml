# %%
# !wget https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv
# Out:
# zsh:1: command not found: wget

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/foroghakbari/Zoomcamp/ml_course/zoomcamp_ml/regression/car_fuel_efficiency_2026.csv')

# %%
df
# Out:
#       model_year  origin fuel_type         drivetrain  num_doors  \
# 0           2006  Europe  Gasoline  Front-wheel drive          4
# 1           2008  Europe    Diesel  Front-wheel drive          4
# 2           1996    Asia  Gasoline  Front-wheel drive          5
# 3           1989  Europe  Gasoline  Front-wheel drive          4
# 4           1994     USA    Diesel  Front-wheel drive          3
# ...          ...     ...       ...                ...        ...
# 9995        2005     USA  Gasoline    All-wheel drive          4
# 9996        1993    Asia  Gasoline    All-wheel drive          2
# 9997        2014     USA  Gasoline    All-wheel drive          3
# 9998        2004     USA    Hybrid   Rear-wheel drive          5
# 9999        2011     USA    Diesel  Front-wheel drive          4
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                    2180              6       243.0            3870
# 1                    2390              6       272.0            4210
# 2                    2320              6       267.0            4240
# 3                    2130              6       258.0            4490
# 4                    2580              7       304.0            4510
# ...                   ...            ...         ...             ...
# 9995                 2470              6       271.0            4690
# 9996                 2300              6       244.0            4370
# 9997                 2480              6       267.0            4590
# 9998                 2180              6       270.0            4450
# 9999                 2380              6       295.0            4370
#
#       acceleration  fuel_efficiency_mpg
# 0              NaN                 31.9
# 1              NaN                 31.3
# 2             17.3                 27.5
# 3             18.7                 28.5
# 4             17.5                 31.0
# ...            ...                  ...
# 9995          18.9                 27.4
# 9996          19.0                 30.0
# 9997          18.4                 28.1
# 9998          20.9                 32.2
# 9999          17.6                 30.2
#
# [10000 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Preparing the dataset
# Use only the following columns:
#
# 'engine_displacement',
# 'horsepower',
# 'vehicle_weight',
# 'model_year',
# 'fuel_efficiency_mpg'
# EDA
# Look at the fuel_efficiency_mpg variable. Does it have a long tail?

# %%
df =df[['engine_displacement',
'horsepower',
'vehicle_weight',
'model_year',
'fuel_efficiency_mpg']]

# %%
df
# Out:
#       engine_displacement  horsepower  vehicle_weight  model_year  \
# 0                    2180       243.0            3870        2006
# 1                    2390       272.0            4210        2008
# 2                    2320       267.0            4240        1996
# 3                    2130       258.0            4490        1989
# 4                    2580       304.0            4510        1994
# ...                   ...         ...             ...         ...
# 9995                 2470       271.0            4690        2005
# 9996                 2300       244.0            4370        1993
# 9997                 2480       267.0            4590        2014
# 9998                 2180       270.0            4450        2004
# 9999                 2380       295.0            4370        2011
#
#       fuel_efficiency_mpg
# 0                    31.9
# 1                    31.3
# 2                    27.5
# 3                    28.5
# 4                    31.0
# ...                   ...
# 9995                 27.4
# 9996                 30.0
# 9997                 28.1
# 9998                 32.2
# 9999                 30.2
#
# [10000 rows x 5 columns]

# %%
sns.histplot(df.fuel_efficiency_mpg, bins=50)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='fuel_efficiency_mpg', ylabel='Count'>

# %%
df.count()
# Out:
# engine_displacement    10000
# horsepower              9123
# vehicle_weight         10000
# model_year             10000
# fuel_efficiency_mpg    10000
# dtype: int64

# %%
df.isna().sum() #number of NAs 877
# Out:
# engine_displacement      0
# horsepower             877
# vehicle_weight           0
# model_year               0
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df['horsepower'].median()
# Out:
# 254.0

# %%
#splitting data

# %%
n = len(df)
n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = n - n_val - n_test

# %%
np.random.seed(42)
idx = np.arange(n)
np.random.shuffle(idx)

df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train + n_val]]
df_test = df.iloc[idx[n_train + n_val:]]

# %%
df_train
# Out:
#       engine_displacement  horsepower  vehicle_weight  model_year  \
# 6252                 1900       239.0            3790        2015
# 4684                 2000       224.0            4380        1992
# 1731                 2330       286.0            4090        2022
# 4742                 2300         NaN            4150        1997
# 4521                 2340       269.0            4400        2001
# ...                   ...         ...             ...         ...
# 7895                 2280       242.0            4590        2018
# 9590                 2300         NaN            4240        1984
# 7288                 2240       255.0            4190        1989
# 278                  2430       254.0            4280        2020
# 3252                 2390       266.0            4220        1996
#
#       fuel_efficiency_mpg
# 6252                 32.5
# 4684                 29.1
# 1731                 34.1
# 4742                 30.6
# 4521                 30.7
# ...                   ...
# 7895                 29.8
# 9590                 25.1
# 7288                 27.7
# 278                  31.6
# 3252                 28.0
#
# [6000 rows x 5 columns]

# %%
df_filled = df.fillna(0)

# %%
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].mean())
# Out:
# /var/folders/yp/fcwsrmjd6fd_161hmt7py7l00000gn/T/ipykernel_3795/933759819.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['horsepower'] = df['horsepower'].fillna(df['horsepower'].mean())

# %%
df
# Out:
#       engine_displacement  horsepower  vehicle_weight  model_year  \
# 0                    2180       243.0            3870        2006
# 1                    2390       272.0            4210        2008
# 2                    2320       267.0            4240        1996
# 3                    2130       258.0            4490        1989
# 4                    2580       304.0            4510        1994
# ...                   ...         ...             ...         ...
# 9995                 2470       271.0            4690        2005
# 9996                 2300       244.0            4370        1993
# 9997                 2480       267.0            4590        2014
# 9998                 2180       270.0            4450        2004
# 9999                 2380       295.0            4370        2011
#
#       fuel_efficiency_mpg
# 0                    31.9
# 1                    31.3
# 2                    27.5
# 3                    28.5
# 4                    31.0
# ...                   ...
# 9995                 27.4
# 9996                 30.0
# 9997                 28.1
# 9998                 32.2
# 9999                 30.2
#
# [10000 rows x 5 columns]
