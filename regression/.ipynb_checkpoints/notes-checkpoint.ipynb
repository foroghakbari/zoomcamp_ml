# %% [markdown]
# ## regression notes

# %%
import pandas as pd
import subprocess
import requests
import numpy as np

# %%
df = pd.read_csv('/Users/foroghakbari/Zoomcamp/ml_course/zoomcamp_ml/regression/data.csv')

# %%
df.head()
df.columns.str.lower()
# Out:
# Index(['make', 'model', 'year', 'engine fuel type', 'engine hp',
#        'engine cylinders', 'transmission type', 'driven_wheels',
#        'number of doors', 'market category', 'vehicle size', 'vehicle style',
#        'highway mpg', 'city mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# make                 object
# model                object
# engine_fuel_type     object
# transmission_type    object
# driven_wheels        object
# market_category      object
# vehicle_size         object
# vehicle_style        object
# dtype: object

# %%
strings = list(df.dtypes[df.dtypes == 'object'].index)
strings
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
for col in strings:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# make
# ['bmw' 'audi' 'fiat' 'mercedes-benz' 'chrysler']
# 48
#
# model
# ['1_series_m' '1_series' '100' '124_spider' '190-class']
# 914
#
# year
# [2011 2012 2013 1992 1993]
# 28
#
# engine_fuel_type
# ['premium_unleaded_(required)' 'regular_unleaded'
#  'premium_unleaded_(recommended)' 'flex-fuel_(unleaded/e85)' 'diesel']
# 10
#
# engine_hp
# [335. 300. 230. 320. 172.]
# 356
#
# engine_cylinders
# [ 6.  4.  5.  8. 12.]
# 9
#
# transmission_type
# ['manual' 'automatic' 'automated_manual' 'direct_drive' 'unknown']
# 5
#
# driven_wheels
# ['rear_wheel_drive' 'front_wheel_drive' 'all_wheel_drive'
#  'four_wheel_drive']
# 4
#
# number_of_doors
# [ 2.  4.  3. nan]
# 3
#
# market_category
# ['factory_tuner,luxury,high-performance' 'luxury,performance'
#  'luxury,high-performance' 'luxury' 'performance']
# 71
#
# vehicle_size
# ['compact' 'midsize' 'large']
# 3
#
# vehicle_style
# ['coupe' 'convertible' 'sedan' 'wagon' '4dr_hatchback']
# 16
#
# highway_mpg
# [26 28 27 25 24]
# 59
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.histplot(df.msrp, bins=50)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
sns.histplot(df.msrp[df.msrp < 100000], bins=50) #to get  a better view of the distribution
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
np.log([0 + 1, 1 + 1, 10 + 1, 1000 + 1, 100000 + 1])
# Out:
# array([ 0.        ,  0.69314718,  2.39789527,  6.90875478, 11.51293546])

# %%
np.log1p([0, 1, 10, 1000, 100000])
# Out:
# array([ 0.        ,  0.69314718,  2.39789527,  6.90875478, 11.51293546])

# %%
price_logs = np.log1p(df.msrp)

# %%
sns.histplot(price_logs, bins=50) #looks more normal distributed
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %%
## training, validation and testing

# %%
n =len(df)

# %%
n
# Out:
# 11914

# %%
n_val = int(n * 0.2) #to do a 60/20/20 split- to calculate how many records have 20%
n_test = int(n * 0.2)
n_train = n - n_val - n_test

# %%
n, n_val, n_test, n_train
# Out:
# (11914, 2382, 2382, 7150)

# %%
df.iloc[:10]
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 5  bmw    1_series  2012  premium_unleaded_(required)      230.0
# 6  bmw    1_series  2012  premium_unleaded_(required)      300.0
# 7  bmw    1_series  2012  premium_unleaded_(required)      300.0
# 8  bmw    1_series  2012  premium_unleaded_(required)      230.0
# 9  bmw    1_series  2013  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# ...

# %%
df.iloc[:10]
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 5  bmw    1_series  2012  premium_unleaded_(required)      230.0
# 6  bmw    1_series  2012  premium_unleaded_(required)      300.0
# 7  bmw    1_series  2012  premium_unleaded_(required)      300.0
# 8  bmw    1_series  2012  premium_unleaded_(required)      230.0
# 9  bmw    1_series  2013  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# ...

# %%
df_val = df.iloc[:n_val]
df_test = df.iloc[n_val:n_val+n_test]
df_train = df.iloc[n_val+n_test:]

#issue here is that its sequential and not random e.g. all one type of car is at the front etc. so the data is not representative.

# %%
df_val
# Out:
#          make       model  year             engine_fuel_type  engine_hp  \
# 0         bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1         bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2         bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3         bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4         bmw    1_series  2011  premium_unleaded_(required)      230.0
# ...       ...         ...   ...                          ...        ...
# 2377  porsche     cayenne  2016  premium_unleaded_(required)      570.0
# 2378  porsche     cayenne  2016                       diesel      240.0
# 2379  porsche     cayenne  2017  premium_unleaded_(required)      520.0
# 2380  porsche     cayenne  2017  premium_unleaded_(required)      300.0
# 2381  porsche     cayenne  2017  premium_unleaded_(required)      440.0
#
#       engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# ...

# %%
#need to random shuffle, using numpy to shuffle an arbitrary sequence 

idx = np.arange(n)
np.random.shuffle(idx)

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train+n_val]]
df_test = df.iloc[idx[n_train+n_val:]]

# %%
df_val
# Out:
#                 make           model  year                engine_fuel_type  \
# 11572          volvo            xc60  2015                regular_unleaded
# 9034           lexus          sc_300  1998                regular_unleaded
# 7545      volkswagen         phaeton  2005  premium_unleaded_(recommended)
# 4824          suzuki         forenza  2008                regular_unleaded
# 9676   mercedes-benz       slk-class  2015     premium_unleaded_(required)
# ...              ...             ...   ...                             ...
# 2059   mercedes-benz         c-class  2015     premium_unleaded_(required)
# 10068        pontiac         sunbird  1993                regular_unleaded
# 8988         hyundai        santa_fe  2015                regular_unleaded
# 5814       chevrolet  impala_limited  2014        flex-fuel_(unleaded/e85)
# 11415       chrysler         voyager  2002                regular_unleaded
#
# ...

# %%
#one more issue- getting different records first car will not be a porsche / gmc- REPRODUCIBLE.
#set a random seed
np.random.seed(2)

idx = np.arange(n)
np.random.shuffle(idx)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (7150, 2382, 2382)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = np.log1p(df_train.msrp.values)
y_val = np.log1p(df_val.msrp.values)
y_test = np.log1p(df_test.msrp.values)

# %%
y_train
# Out:
# array([ 7.95050243, 10.36898103,  7.60140233, ..., 10.17736224,
#         9.97678448, 10.68168794])

# %%
del df_train['msrp']
del df_val['msrp']
del df_test['msrp']

# %%
#linear regression

# %%
xi = [453, 11, 86]
w0 = 7.17 #intercept/bias term
w = [0.01, 0.04, 0.002]

# %%
def linear_regression(xi):
    n = len(xi)

    pred = w0

    for j in range(n):
        pred = pred + w[j] * xi[j]

    return pred

# %%
linear_regression(xi)
# Out:
# 12.312

# %%
#w0 when we have no predictors/know nothing about the car

# %%
#log transformation 
np.expm1(12.312)
# Out:
# 222347.2221101062

# %%
def dot(xi, w):
    n = len(xi)

    res = 0.0

    for j in range(n):
        res = res + xi[j] * w[j]

    return res

# %%
def linear_regression(xi):
    return w0 + dot(xi, w)

# %%
w_new = [w0] + w

# %%
w_new
# Out:
# [7.17, 0.01, 0.04, 0.002]

# %%
def linear_regression(xi):
    xi = [1] + xi
    return dot(xi, w_new)

# %%
linear_regression(xi)
# Out:
# 12.312

# %%
xi = [453, 11, 86]
w0 = 7.17 #intercept/bias term
w = [0.01, 0.04, 0.002]

# %%
x1  = [1, 148, 24, 1385]
x2  = [1, 132, 25, 2031]
x10 = [1, 453, 11, 86]

X = [x1, x2, x10]
X = np.array(X)

# %%
X
# Out:
# array([[   1,  148,   24, 1385],
#        [   1,  132,   25, 2031],
#        [   1,  453,   11,   86]])

# %%
w0 = 7.17
w = [0.01, 0.04, 0.002]
w_new = [w0] + w

# %%
#function 
def linear_regression(X):
    return X.dot(w_new)

# %%
price=linear_regression(X) #in logs

# %%
dollar= np.expm1(price)

# %%
dollar
# Out:
# array([237992.82334859, 768348.51018973, 222347.22211011])

# %%
#training lM

# %%
X = [
    [148, 24, 1385],
    [132, 25, 2031],
    [453, 11, 86],
    [158, 24, 185],
    [172, 25, 201],
    [413, 11, 86],
    [38,  54, 185],
    [142, 25, 431],
    [453, 31, 86],
]
X = np.array(X)

# %%
XTX = X.T.dot(X)

# %%
XTX
# Out:
# array([[ 696471,   44115,  718540],
#        [  44115,    7146,  118803],
#        [ 718540,  118803, 6359986]])

# %%
#Inverse
XTX_inv = np.linalg.inv(XTX)

# %%
XTX.dot(XTX_inv).round(1)
# Out:
# array([[ 1.,  0.,  0.],
#        [-0.,  1.,  0.],
#        [ 0.,  0.,  1.]])

# %%
#target 
y = [100, 200, 150, 250, 100, 200, 150, 250, 120]

# %%
#equation 
w_full = XTX_inv.dot(X.T).dot(y)

# %%
w_full
# Out:
# array([0.26190562, 3.06101252, 0.03696909])

# %%
ones = np.ones(X.shape[0])
X = np.column_stack([ones, X])
XTX = X.T.dot(X)
XTX_inv = np.linalg.inv(XTX)
w_full = XTX_inv.dot(X.T).dot(y)

# %%
w0 = w_full[0]
w = w_full[1:]

# %%
w0, w
# Out:
# (300.0677669255554, array([-0.22774253, -2.5769413 , -0.02301206]))

# %%
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)

    return w_full[0], w_full[1:]

# %%
train_linear_regression(X, y)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 train_linear_regression(X, y)
#
# Cell In[70], line 6, in train_linear_regression(X, y)
#       3 X = np.column_stack([ones, X])
#       5 XTX = X.T.dot(X)
# ----> 6 XTX_inv = np.linalg.inv(XTX)
#       7 w_full = XTX_inv.dot(X.T).dot(y)
#       9 return w_full[0], w_full[1:]
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:561, in inv(a)
#     559 signature = 'D->D' if isComplexType(t) else 'd->d'
#     560 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 561 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     562 return wrap(ainv.astype(result_t, copy=False))
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:112, in _raise_linalgerror_singular(err, flag)
#     111 def _raise_linalgerror_singular(err, flag):
# ...

# %%
## pred for car

# %%
df_train.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
df_train.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity'],
#       dtype='object')

# %%
base = ['engine_hp','engine_cylinders','highway_mpg','city_mpg','popularity']

# %%
base
# Out:
# ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
X_train = df_train[base].values

# %%
X_train
# Out:
# array([[2.200e+02, 8.000e+00, 1.700e+01, 1.200e+01, 5.657e+03],
#        [2.000e+02, 4.000e+00, 2.500e+01, 1.900e+01, 5.490e+02],
#        [1.650e+02, 6.000e+00, 2.000e+01, 1.500e+01, 1.385e+03],
#        ...,
#        [2.610e+02, 6.000e+00, 2.000e+01, 1.600e+01, 2.009e+03],
#        [2.100e+02, 6.000e+00, 2.000e+01, 1.400e+01, 1.851e+03],
#        [2.200e+02, 4.000e+00, 3.400e+01, 2.500e+01, 3.105e+03]])

# %%
y_train
# Out:
# array([ 7.95050243, 10.36898103,  7.60140233, ..., 10.17736224,
#         9.97678448, 10.68168794])

# %%
train_linear_regression(X_train, y_train) #all nans, missing values
# Out:
# (nan, array([nan, nan, nan, nan, nan]))

# %%
#fill nans with 0s
df_train[base].isnull().sum()
# Out:
# engine_hp           41
# engine_cylinders    16
# highway_mpg          0
# city_mpg             0
# popularity           0
# dtype: int64

# %%
X_train = df_train[base].fillna(0)
#best way to deal with missing data?

# %%
w0, w = train_linear_regression(X_train, y_train) #all nans, missing values

# %%
y_pred = w0 + X_train.dot(w)

# %%
sns.histplot(y_pred, color='red')
sns.histplot(y_train)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
#RMSE

# %%
#how can we quantify how 'off' predictions are from target y?

# %%
def rmse(y, y_pred):
    error = y - y_pred
    se = error **2
    mse= se.mean()
    return np.sqrt(mse)

# %%
rmse(y_train, y_pred)
# Out:
# 0.7580648382168246

# %%
#validation

# %%
base = ['engine_hp','engine_cylinders','highway_mpg','city_mpg','popularity']
X_train = df_train[base].fillna(0).values
w0, w = train_linear_regression(X_train, y_train) #all nans, missing values
y_pred = w0 + X_train.dot(w)

# %%
def prepare_X(df):
    df_num = df[base]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)

# %%
w0, w = train_linear_regression(X_train, y_train) 

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# 0.7451811932611363

# %%
rmse(y_val, y_pred)
# Out:
# 0.7451811932611363

# %%
#feature engineering

# %%
df_train.year.max()
# Out:
# 2017

# %%
def prepare_X(df):
    df = df.copy()
    
    df['age'] = 2017 - df.year
    features = base +['age']
    
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)

# %%
X_train
# Out:
# array([[2.200e+02, 8.000e+00, 1.700e+01, 1.200e+01, 5.657e+03, 2.000e+01],
#        [2.000e+02, 4.000e+00, 2.500e+01, 1.900e+01, 5.490e+02, 1.000e+00],
#        [1.650e+02, 6.000e+00, 2.000e+01, 1.500e+01, 1.385e+03, 2.300e+01],
#        ...,
#        [2.610e+02, 6.000e+00, 2.000e+01, 1.600e+01, 2.009e+03, 3.000e+00],
#        [2.100e+02, 6.000e+00, 2.000e+01, 1.400e+01, 1.851e+03, 8.000e+00],
#        [2.200e+02, 4.000e+00, 3.400e+01, 2.500e+01, 3.105e+03, 0.000e+00]])

# %%
w0, w = train_linear_regression(X_train, y_train) 

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# 0.5198973637281054

# %%
sns.histplot(y_pred, color='red')
sns.histplot(y_val)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
#cateogorical variables

# %%
#number of doors

# %%
df_train
# Out:
#             make            model  year                engine_fuel_type  \
# 0           ford            f-250  1997                regular_unleaded
# 1            gmc           canyon  2016                regular_unleaded
# 2      chevrolet      s-10_blazer  1994                regular_unleaded
# 3       cadillac           catera  2000                regular_unleaded
# 4           saab              900  1997                regular_unleaded
# ...          ...              ...   ...                             ...
# 7145  volkswagen               cc  2016  premium_unleaded_(recommended)
# 7146      subaru          outback  2015                regular_unleaded
# 7147      nissan           xterra  2014                regular_unleaded
# 7148       dodge  ram_pickup_1500  2009                regular_unleaded
# 7149        audi               a3  2017  premium_unleaded_(recommended)
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_train['num_doors_2']=(df_train.number_of_doors == 2).astype('int')
df_train['num_doors_4']=(df_train.number_of_doors == 4).astype('int')
df_train['num_doors_4']=(df_train.number_of_doors == 4).astype('int')
df_train['num_doors_4']=(df_train.number_of_doors == 4).astype('int')

# %%
for v in [2,3,4]:
    df_train['num_doors_%s' % v] = (df_train.number_of_doors == v).astype('int')

# %%
df_train
# Out:
#             make            model  year                engine_fuel_type  \
# 0           ford            f-250  1997                regular_unleaded
# 1            gmc           canyon  2016                regular_unleaded
# 2      chevrolet      s-10_blazer  1994                regular_unleaded
# 3       cadillac           catera  2000                regular_unleaded
# 4           saab              900  1997                regular_unleaded
# ...          ...              ...   ...                             ...
# 7145  volkswagen               cc  2016  premium_unleaded_(recommended)
# 7146      subaru          outback  2015                regular_unleaded
# 7147      nissan           xterra  2014                regular_unleaded
# 7148       dodge  ram_pickup_1500  2009                regular_unleaded
# 7149        audi               a3  2017  premium_unleaded_(recommended)
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()

    df['age'] = 2017 - df.year
    features.append('age')

    for v in [2, 3, 4]:
        df['num_doors_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('num_doors_%s' % v)

    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# 0.5164626483662098

# %%
X_train
# Out:
# array([[220.,   8.,  17., ...,   0.,   1.,   0.],
#        [200.,   4.,  25., ...,   0.,   0.,   1.],
#        [165.,   6.,  20., ...,   0.,   0.,   1.],
#        ...,
#        [261.,   6.,  20., ...,   0.,   0.,   1.],
#        [210.,   6.,  20., ...,   1.,   0.,   0.],
#        [220.,   4.,  34., ...,   1.,   0.,   0.]])

# %%
df.make.value_counts().head()
# Out:
# make
# chevrolet     1123
# ford           881
# volkswagen     809
# toyota         746
# dodge          626
# Name: count, dtype: int64

# %%
makes = list(df.make.value_counts().head().index)

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()

    df['age'] = 2017 - df.year
    features.append('age')

    for v in [2, 3, 4]:
        df['num_doors_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('num_doors_%s' % v)
    for v in makes:
        df['make_%s' % v] = (df.make == v).astype('int')
        features.append('make_%s' % v)

    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# 0.5069034840005202

# %%
#all cate vars

categorical_variables = [
    'make', 'engine_fuel_type', 'transmission_type', 'driven_wheels',
    'market_category', 'vehicle_size', 'vehicle_style'
]

categories = {}

for c in categorical_variables:
    categories[c] = list(df_train[c].value_counts().head().index)

# %%
categories
# Out:
# {'make': ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge'],
#  'engine_fuel_type': ['regular_unleaded',
#   'premium_unleaded_(required)',
#   'premium_unleaded_(recommended)',
#   'flex-fuel_(unleaded/e85)',
#   'diesel'],
#  'transmission_type': ['automatic',
#   'manual',
#   'automated_manual',
#   'direct_drive',
#   'unknown'],
#  'driven_wheels': ['front_wheel_drive',
#   'rear_wheel_drive',
#   'all_wheel_drive',
#   'four_wheel_drive'],
#  'market_category': ['crossover',
#   'flex_fuel',
#   'luxury',
#   'luxury,performance',
#   'hatchback'],
#  'vehicle_size': ['compact', 'midsize', 'large'],
#  'vehicle_style': ['sedan',
#   '4dr_suv',
#   'coupe',
#   'convertible',
#   '4dr_hatchback']}

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()

    df['age'] = 2017 - df.year
    features.append('age')

    for v in [2, 3, 4]:
        df['num_doors_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('num_doors_%s' % v)
    for v in makes:
        df['make_%s' % v] = (df.make == v).astype('int')
        features.append('make_%s' % v)
    
    for c, values in categories.items():
        for v in values:
            df['%s_%s' % (c, v)] = (df[c] == v).astype('int')
            features.append('%s_%s' % (c, v))

    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# 278.2075187171591

# %%
w
# Out:
# array([-1.61970786e+00,  1.89961948e+02,  1.54950938e+01,  4.19835303e+00,
#        -4.33551917e-02,  2.06122764e-01, -1.60226474e+03, -1.63820061e+03,
#        -1.61198398e+03, -1.99325008e+16, -1.71269931e+16,  5.48542521e+16,
#         9.50406932e+16,  6.83301681e+17,  1.99325008e+16,  1.71269931e+16,
#        -5.48542521e+16, -9.50406932e+16, -6.83301681e+17,  6.70115347e+01,
#         6.28271413e+01,  6.17585965e+01,  6.98791636e+01, -2.35051155e+01,
#         1.21872567e+16,  1.21872567e+16,  1.21872567e+16,  1.21872567e+16,
#         1.21872567e+16, -5.98044689e+15, -5.98044689e+15, -5.98044689e+15,
#        -5.98044689e+15,  3.81151990e+00,  5.01904117e+00, -6.50174816e+00,
#         2.72005507e+00, -4.88163184e+00, -4.34945942e+01, -2.45538172e+01,
#        -2.46734576e+01, -6.13098492e-02,  4.94674940e-02,  1.53074030e-01,
#         3.28426931e-01, -1.55678336e-01])

# %%
#what went wrong rmse increased.

# %%
#categorical vars to our model ended up with RMSE and weights were big- regularisation as a solution

# %%
X = [
    [4, 4, 4],
    [3, 5, 5],
    [5, 1, 1],
    [5, 4, 4],
    [7, 5, 5],
    [4, 5, 5],
]

# %%
X = np.array(X)

# %%
X
# Out:
# array([[4, 4, 4],
#        [3, 5, 5],
#        [5, 1, 1],
#        [5, 4, 4],
#        [7, 5, 5],
#        [4, 5, 5]])

# %%
XTX=X.T.dot(X) #same values, duplicated and inverse doesnt exist

# %%
X = [
    [4, 4, 4],
    [3, 5, 5],
    [5, 1, 1],
    [5, 4, 4],
    [7, 5, 5],
    [4, 5, 5.00000001],
]
X = np.array(X)

# %%
XTX=X.T.dot(X) 
XTX
# Out:
# array([[140.        , 111.        , 111.00000004],
#        [111.        , 108.        , 108.00000005],
#        [111.00000004, 108.00000005, 108.0000001 ]])

# %%
y=[1,2,3,1,2,3]

# %%
XTX_inv = np.linalg.inv(XTX)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 XTX_inv = np.linalg.inv(XTX)
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:561, in inv(a)
#     559 signature = 'D->D' if isComplexType(t) else 'd->d'
#     560 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 561 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     562 return wrap(ainv.astype(result_t, copy=False))
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:112, in _raise_linalgerror_singular(err, flag)
#     111 def _raise_linalgerror_singular(err, flag):
# --> 112     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
XTX_inv.dot(X.T).dot(y)

# %%
XTX = [
    [1, 2, 2],
    [2, 1, 1],
    [2, 1, 1],
]

# %%
XTX = [
    [1, 2, 2],
    [2, 1, 1.0000001],
    [2, 1.0000001, 1],
]

# %%
XTX_inv = np.linalg.inv(XTX)

# %%
XTX_inv
# Out:
# array([[-3.33333356e-01,  3.33333339e-01,  3.33333339e-01],
#        [ 3.33333339e-01, -5.00000008e+06,  4.99999991e+06],
#        [ 3.33333339e-01,  4.99999991e+06, -5.00000008e+06]])

# %% [markdown]
# To solve this problem, we can add a small number to the diagonal of the matrix. If we add a small number to the diagonal - say 0.01 - the inverse can still be found, and the numbers in it are much more under control. The larger the number we add to the diagonal, the more control we get over the weights.

# %%
XTX + np.eye(3)
# Out:
# array([[2.       , 2.       , 2.       ],
#        [2.       , 2.       , 1.0000001],
#        [2.       , 1.0000001, 2.       ]])

# %%
XTX = XTX + 0.01 * np.eye(3)

# %%
XTX_inv = np.linalg.inv(XTX)

# %%
XTX_inv
# Out:
# array([[ -0.33668908,   0.33501399,   0.33501399],
#        [  0.33501399,  49.91590897, -50.08509104],
#        [  0.33501399, -50.08509104,  49.91590897]])

# %%
def train_linear_regression_reg(X, y, r=0.001):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X) #regularisation
    XTX = XTX + r * np.eye(XTX.shape[0])

    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)

    return w_full[0], w_full[1:]

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression_reg(X_train, y_train, r=0.001)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# 0.45580666021266875

# %%
sns.histplot(y_pred, color='red')
sns.histplot(y_val)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
##finding regularisation params for tuning

# %%
for r in [0.0, 0.00001, 0.0001, 0.001, 0.1, 1, 10]:
    X_train = prepare_X(df_train)
    w0, w = train_linear_regression_reg(X_train, y_train, r=r)

    X_val = prepare_X(df_val)
    y_pred = w0 + X_val.dot(w)
    score = rmse(y_val, y_pred)

    print(r, w0, score) #diff values of r to applied to the model
# Out:
# 0.0 -6206809800533661.0 278.2075187171591
# 1e-05 7.673787007611165 0.4558068257663136
# 0.0001 6.310264901074365 0.45580679430756427
# 0.001 6.3026157604045885 0.45580666021266875
# 0.1 6.143909793248425 0.4558258323606277
# 1 5.439126099464934 0.4567485883827313
# 10 4.225123712318344 0.4680560687034609

# %% [markdown]
# What we see: for zero regularization the bias term is huge and the RMSE is huge too - 266. That is the broken model with the duplicated columns problem. But for even a little bit of regularization it improves immediately, and after that the score doesn't really change that much. It starts to become a bit worse as we increase the regularization, and when it's 10 it's even worse.

# %%
#smaller vias is 0.001

# %%
r = 0.001
X_train = prepare_X(df_train)
w0, w = train_linear_regression_reg(X_train, y_train, r=r)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
score = rmse(y_val, y_pred)
score
# Out:
# 0.45580666021266875

# %%
#using the model

# %% [markdown]
# for the final model we do something different: we combine the training and validation datasets into one - let's call it full_train - train the model on all of it, and then make the final evaluation on the test dataset.

# %%
df_full_train = pd.concat([df_train, df_val])

# %%
df_full_train
# Out:
#                make           model  year             engine_fuel_type  \
# 0              ford           f-250  1997             regular_unleaded
# 1               gmc          canyon  2016             regular_unleaded
# 2         chevrolet     s-10_blazer  1994             regular_unleaded
# 3          cadillac          catera  2000             regular_unleaded
# 4              saab             900  1997             regular_unleaded
# ...             ...             ...   ...                          ...
# 2377  mercedes-benz         c-class  2015  premium_unleaded_(required)
# 2378        pontiac         sunbird  1993             regular_unleaded
# 2379        hyundai        santa_fe  2015             regular_unleaded
# 2380      chevrolet  impala_limited  2014     flex-fuel_(unleaded/e85)
# 2381       chrysler         voyager  2002             regular_unleaded
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_full_train = df_full_train.reset_index(drop=True)

# %%
df_full_train
# Out:
#                make           model  year             engine_fuel_type  \
# 0              ford           f-250  1997             regular_unleaded
# 1               gmc          canyon  2016             regular_unleaded
# 2         chevrolet     s-10_blazer  1994             regular_unleaded
# 3          cadillac          catera  2000             regular_unleaded
# 4              saab             900  1997             regular_unleaded
# ...             ...             ...   ...                          ...
# 9527  mercedes-benz         c-class  2015  premium_unleaded_(required)
# 9528        pontiac         sunbird  1993             regular_unleaded
# 9529        hyundai        santa_fe  2015             regular_unleaded
# 9530      chevrolet  impala_limited  2014     flex-fuel_(unleaded/e85)
# 9531       chrysler         voyager  2002             regular_unleaded
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
X_full_train = prepare_X(df_full_train)

# %%
X_full_train
# Out:
# array([[220.,   8.,  17., ...,   0.,   0.,   0.],
#        [200.,   4.,  25., ...,   0.,   0.,   0.],
#        [165.,   6.,  20., ...,   0.,   0.,   0.],
#        ...,
#        [290.,   6.,  25., ...,   0.,   0.,   0.],
#        [300.,   6.,  30., ...,   0.,   0.,   0.],
#        [150.,   4.,  24., ...,   0.,   0.,   0.]])

# %%
y_full_train = np.concatenate([y_train, y_val])

# %%
y_full_train
# Out:
# array([ 7.95050243, 10.36898103,  7.60140233, ..., 10.44147104,
#        10.19768585,  9.70692507])

# %%
w0, w = train_linear_regression_reg(X_full_train, y_full_train, r=0.001)

# %%
w0
# Out:
# 6.307897687586406

# %%
X_test = prepare_X(df_test)
y_pred = w0 + X_test.dot(w)
score = rmse(y_test, y_pred)
score
# Out:
# 0.46836403872945787

# %%
#predicting price of car

# %%
car = df_test.iloc[20].to_dict()
car
# Out:
# {'make': 'porsche',
#  'model': 'cayenne',
#  'year': 2015,
#  'engine_fuel_type': 'premium_unleaded_(required)',
#  'engine_hp': 520.0,
#  'engine_cylinders': 8.0,
#  'transmission_type': 'automatic',
#  'driven_wheels': 'all_wheel_drive',
#  'number_of_doors': 4.0,
#  'market_category': 'crossover,luxury,performance',
#  'vehicle_size': 'midsize',
#  'vehicle_style': '4dr_suv',
#  'highway_mpg': 21,
#  'city_mpg': 14,
#  'popularity': 1715}

# %%
df_small = pd.DataFrame([car])
X_small = prepare_X(df_small)

# %%
X_small
# Out:
# array([[5.200e+02, 8.000e+00, 2.100e+01, 1.400e+01, 1.715e+03, 2.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00]])

# %%
y_pred = w0 + X_small.dot(w)
y_pred = y_pred[0]
y_pred
# Out:
# 11.857228445952575

# %%
np.expm1(y_pred)
# Out:
# 141099.60787586603

# %%
np.expm1(y_test[20])
# Out:
# 113599.99999999991
